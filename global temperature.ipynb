# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel(r'D:\temperature_csv.xlsx')
datanew = pd.read_excel(r'D:\data_csv.xlsx')
x=data['Year']
y=data['Mean']
plt.xlabel('TEMPERATURE',fontsize=18)
plt.ylabel('YEAR',fontsize=16)
plt.scatter(x,y)
plt.plot(x,y)
plt.show()
plt.xlabel('TEMPERATURE',fontsize=18)
plt.ylabel('YEAR',fontsize=16)
plt.bar(x,y)
datanew
plt.show()

# %%
data
# Out:
#     Year    Mean
# 0   2016  0.9363
# 1   2016  0.9900
# 2   2015  0.8998
# 3   2015  0.8700
# 4   2014  0.7408
# 5   2014  0.7400
# 6   2013  0.6679
# 7   2013  0.6500
# 8   2012  0.6240
# 9   2012  0.6300
# 10  2011  0.5788
# 11  2011  0.6000
# 12  2010  0.7014
# 13  2010  0.7100
# 14  2009  0.6367
# 15  2009  0.6400
# 16  2008  0.5419
# 17  2008  0.5400
# 18  2007  0.6100
# 19  2007  0.6600
# 20  2006  0.6125
# 21  2006  0.6300
# 22  2005  0.6585
# 23  2005  0.6900
# 24  2004  0.5783
# 25  2004  0.5500
# 26  2003  0.6134
# 27  2003  0.6200
# 28  2002  0.6023
# 29  2002  0.6300
# 30  2001  0.5473
# 31  2001  0.5500
# 32  2000  0.4262
# 33  2000  0.4200
# 34  1999  0.4438
# 35  1999  0.4200
# 36  1998  0.6344
# 37  1998  0.6400
# 38  1997  0.5187
# 39  1997  0.4800
# 40  1996  0.3228
# 41  1996  0.3500

# %%
datanew
# Out:
#     Year    Mean
# 0   2016  0.9363
# 1   2015  0.8998
# 2   2014  0.7400
# 3   2013  0.6500
# 4   2012  0.6300
# 5   2011  0.6000
# 6   2010  0.7100
# 7   2009  0.6400
# 8   2008  0.5400
# 9   2007  0.6600
# 10  2006  0.6300
# 11  2005  0.6900
# 12  2004  0.5500
# 13  2003  0.6200
# 14  2002  0.6300
# 15  2001  0.5500
# 16  2000  0.4200
# 17  1999  0.4200
# 18  1998  0.6400
# 19  1997  0.4800
# 20  1996  0.3500
